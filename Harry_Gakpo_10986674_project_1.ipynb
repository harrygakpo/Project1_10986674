# %% [markdown]
# ## Harry Sena Gakpo
# ## ID: 10986674
# ## Department: Biomedical Engineering
# ## SENG 207: Project 1

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats
import csv
print('imported successfully')
# Out:
# imported successfully

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### To pre process data we would need to remove duplicate values and null values
# ### To remove duplicate values,

# %%
df.drop_duplicates()
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### To remove null values,

# %%
df.dropna()
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ###     I removed the null values in the set by applying the dropna method to my dataframe object which is df. This method removes all null vlaues. I used this method because it is easy to use and remember.

# %% [markdown]
# ###
# ### The following code is used to show statistical inferences for the entire dataset

# %%
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %% [markdown]
# ### The following code is used to show statistical inferences for all the columns.

# %%
columns = ['ID', 'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
for i in columns:
    print(df[i].describe())
    print('\n')
# Out:
# count    1601.000000
# mean      801.000000
# std       462.313206
# min         1.000000
# 25%       401.000000
# 50%       801.000000
# 75%      1201.000000
# max      1601.000000
# Name: ID, dtype: float64
#
#
# count    1600.000000
# mean        8.319875
# std         1.740039
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64
#
#
# count    1601.000000
# mean        0.527742
# std         0.178981
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64
#
#
# count    1600.000000
# mean        0.271175
# std         0.194745
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64
#
#
# count    1601.000000
# mean        2.538445
# std         1.409138
# min         0.900000
# ...

# %% [markdown]
# ### The following code shows other inferences like the mode and the variance

# %%
columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
for i in columns:
    print(df[i].mode())
    print('\n')
# Out:
# 0    7.2
# Name: fixed acidity, dtype: float64
#
#
# 0    0.6
# Name: volatile acidity, dtype: float64
#
#
# 0    0.0
# Name: citric acid, dtype: float64
#
#
# 0    2.0
# Name: residual sugar, dtype: float64
#
#
# 0    0.08
# Name: chlorides, dtype: float64
#
#
# 0    6.0
# Name: free sulfur dioxide, dtype: float64
#
#
# 0    28.0
# Name: total sulfur dioxide, dtype: float64
#
#
# 0    0.9972
# Name: density, dtype: float64
#
#
# 0    3.3
# Name: pH, dtype: float64
#
#
# 0    0.6
# Name: sulphates, dtype: float64
#
#
# 0    9.5
# Name: alcohol, dtype: float64
#
#
# 0    5.0
# Name: quality, dtype: float64

# %%
df.var()
# Out:
# ID                      213733.500000
# fixed acidity                3.027735
# volatile acidity             0.032034
# citric acid                  0.037925
# residual sugar               1.985670
# chlorides                    0.002216
# free sulfur dioxide        109.379940
# total sulfur dioxide      1087.530244
# density                      0.000004
# pH                           0.023820
# sulphates                    0.028720
# alcohol                      1.135279
# quality                      0.651843
# dtype: float64

# %% [markdown]
# ### To show data correlation among columns, I used the corr method in the following code.

# %%
matrix = df.corr().round(2)

# %%
print(matrix)
# Out:
#                         ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.00          -0.27             -0.01        -0.15
# fixed acidity        -0.27           1.00             -0.26         0.67
# volatile acidity     -0.01          -0.26              1.00        -0.55
# citric acid          -0.15           0.67             -0.55         1.00
# residual sugar       -0.03           0.11              0.00         0.14
# chlorides            -0.12           0.09              0.06         0.20
# free sulfur dioxide   0.09          -0.15             -0.01        -0.06
# total sulfur dioxide -0.11          -0.11              0.08         0.04
# density              -0.37           0.67              0.02         0.36
# pH                    0.14          -0.68              0.24        -0.54
# sulphates            -0.12           0.18             -0.26         0.31
# alcohol               0.25          -0.06             -0.20         0.11
# ...

# %% [markdown]
# ### This is a heatmap showing the correlation among columns.

# %%
sns.heatmap(matrix, annot=True)
plt.show()

# %% [markdown]
# ## HIDDEN INFERENCES FROM THE HEATMAP DIAGRAM
#
# ###  1. From the heatmap diagram above, the correlations between the various columns can be easily inferred. A deep blue infers a strong positive correlation. As the deepness of the blue color decreases, it infers a weak correlaton as it approaches negative.
# ### 2. From the diagram, it is clearly seen that every column correlates at the maximum positive correlation of 1 against its own colum  and that is reasonable as the values are the same.
# ###  3. Also it can be clearly observed that the correlation between fixed acidity and pH approaches a minimum correlation as their correlation depicts a very very light color
# ### 4. If we take a critical look at the heat map, it can be observed that  free sulfur dioxide and total sulfur dioxide have a pretty strong positive correlation as their correlation blue color is quite deep depicting a strong correlation

# %%
hist_plot=df['total sulfur dioxide'].hist(bins=9)
hist_plot.set_xlabel('amount of the total sulfur dioxide')
hist_plot.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# ## HIDDEN INFERENCE FROM HISTOGRAM
# ### The above histogram is used analyse the frequency of the  amount of the total sulfur dioxide in the entire data set.
# ### It can be observed from the histogram that quantities within the range of 0-50 have the highest number of occurences in the dataset(frequency).
# ### Also values within the range of 150-200 hold the least number of frequency as values between 200-300 does not exist hence no rise in bars over those ranges.
